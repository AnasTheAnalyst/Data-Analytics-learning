# %%
import yfinance as yf
import pandas as pd

# define ticker symbol
tickersymbol = 'TSLA'                   # Every company is change

# # Get data on this ticker
tickerdata = yf.Ticker(tickersymbol)
# tickerdata.info

# get the historical prices of ticker
tickerdf = tickerdata.history(period="1d" , start='2005-1-1' , end= '2020-1-25'  )


# LAST closing price
tickerdf['Close'].iloc[-1]

tickerdf.head()
print(tickerdf.shape)
# Out:
# (2410, 7)

# %%
# Fetch data from last 1 year

import yfinance as yf
import pandas as pd
import datetime as dt
from datetime import date,timedelta


today = date.today()
d1= today.strftime("%Y-%m-%d")
d1

d2= (today-timedelta(days=365)).strftime("%Y-%m-%d")
d2

start_date = d2
end_date = d1

# define ticker symbol
tickersymbol = 'TSLA'                   # Every company is change

# # Get data on this ticker
tickerdata = yf.Ticker(tickersymbol)
# tickerdata.info

# get the historical prices of ticker
tickerdf = tickerdata.history(period="1d" , start= start_date , end= end_date )

tickerdf.head()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2022-09-29 00:00:00-04:00  282.760010  283.649994  265.779999  268.209991
# 2022-09-30 00:00:00-04:00  266.149994  275.570007  262.470001  265.250000
# 2022-10-03 00:00:00-04:00  254.500000  255.160004  241.009995  242.399994
# 2022-10-04 00:00:00-04:00  250.520004  257.500000  242.009995  249.440002
# 2022-10-05 00:00:00-04:00  245.009995  246.669998  233.270004  240.809998
#
#                               Volume  Dividends  Stock Splits
# Date
# 2022-09-29 00:00:00-04:00   77620600        0.0           0.0
# 2022-09-30 00:00:00-04:00   67726600        0.0           0.0
# 2022-10-03 00:00:00-04:00   98363500        0.0           0.0
# 2022-10-04 00:00:00-04:00  109578500        0.0           0.0
# 2022-10-05 00:00:00-04:00   86982700        0.0           0.0
