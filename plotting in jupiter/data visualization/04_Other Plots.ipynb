# %% [markdown]
# # lineplot with multiple facets

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

nuqta =sns.load_dataset("dots")
nuqta.head()

# g=sns.FacetGrid(nuqta , col="choice" ,row="time")
# g.map(sns.relplot ,x="align",y="firing_rate" )
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

sns.set_theme(style="ticks")

kashti =sns.load_dataset("titanic")
kashti



# defining a color palette

p = sns.color_palette('rocket_r')
p

# # plot lineplot

sns.relplot(x='age' ,y='fare',hue="pclass", data=kashti,size="pclass",  kind="line")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

sns.set_theme(style="ticks",palette="pastel")

tip  =sns.load_dataset("tips")
tip

# draw a nested boxplot to show bills by day and time

sns.boxplot(x="day",y="total_bill",hue="smoker",
           palette=["m","g"],
           data=tip)

sns.despine(offset=10,  trim=True)
