# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
pwd = os.getcwd()

# %%
kashti = pd.read_csv(pwd + "./titanic.csv" )
kashti
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
ks = pd.read_csv(pwd + "./titanic.csv" )
ks1 = kashti
ks2 = kashti

# %%
ks1.shape
# Out:
# (891, 12)

# %%
# Simple operations with math operators

(ks1['Age']+6).head(5)
# Out:
# 0    28.0
# 1    44.0
# 2    32.0
# 3    41.0
# 4    41.0
# Name: Age, dtype: float64

# %% [markdown]
# ### Handling of missing values

# %%
# where exactly missing values are
ks1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Dropna method 
# ks1.shape
ks3 = ks1.dropna(subset=['Age'], axis=0 )

# %%
ks3.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          529
# Embarked         2
# dtype: int64

# %%
# to drop na from all dataframe
ks4 = ks3.dropna().inplace = True
ks4 = ks3.isnull().sum()
ks4
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          529
# Embarked         2
# dtype: int64

# %%
ks4.shape
# Out:
# (12,)

# %%
ks4.head()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# dtype: int64

# %%
ks1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ### Replace missing values with the average of tha coloumn

# %%
# finding an average mean

mean= ks1['Age'].mean()
mean
# Out:
# 29.69911764705882

# %%
# replacing nan with mean

ks1['Age'] = ks1['Age'].replace(np.nan , mean)

# %%
ks1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Then we convert age into days instead of year

ks1['Age']= ks1['Age']*365
ks1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex      Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   8030.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  13870.0      1
# 2                             Heikkinen, Miss. Laina  female   9490.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  12775.0      1
# 4                           Allen, Mr. William Henry    male  12775.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
# always rename afterwards

ks1.rename(columns = {"Age":"age in days" } , inplace = True )
ks1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  age in days  \
# 0                            Braund, Mr. Owen Harris    male         8030
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female        13870
# 2                             Heikkinen, Miss. Laina  female         9490
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female        12775
# 4                           Allen, Mr. William Henry    male        12775
#
#    SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      1      0         A/5 21171   7.2500   NaN        S
# 1      1      0          PC 17599  71.2833   C85        C
# 2      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3      1      0            113803  53.1000  C123        S
# ...

# %%
ks1['Age']= ks1['Age'].astype("int64")
ks1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex    Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   8030      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  13870      1
# 2                             Heikkinen, Miss. Laina  female   9490      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  12775      1
# 4                           Allen, Mr. William Henry    male  12775      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Normalization of data
# - Normalization changes the value from 0 to 1(now both variable has similar influence on model)

# %% [markdown]
# ## Method of Normalization

# %% [markdown]
# -- 1 Simple Feature Scaling
# - x(new) =    x(old)/x(max)

# %% [markdown]
# - 2     Min and Maz method
# - 3     Z Score (Stantard Score) -3 to +3
# - 4     Log Transformation

# %%
ks1[["age in days","Fare"]]
# Out:
#      age in days     Fare
# 0           8030   7.2500
# 1          13870  71.2833
# 2           9490   7.9250
# 3          12775  53.1000
# 4          12775   8.0500
# ..           ...      ...
# 886         9855  13.0000
# 887         6935  30.0000
# 888        10840  23.4500
# 889         9490  30.0000
# 890        11680   7.7500
#
# [891 rows x 2 columns]

# %%
# Simple feature Scaling

ks1["Fare"] = ks1["Fare"]/ks1["Fare"].max()
ks1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  age in days  \
# 0                            Braund, Mr. Owen Harris    male         8030
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female        13870
# 2                             Heikkinen, Miss. Laina  female         9490
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female        12775
# 4                           Allen, Mr. William Henry    male        12775
#
#    SibSp  Parch            Ticket      Fare Cabin Embarked
# 0      1      0         A/5 21171  0.014151   NaN        S
# 1      1      0          PC 17599  0.139136   C85        C
# 2      0      0  STON/O2. 3101282  0.015469   NaN        S
# 3      1      0            113803  0.103644  C123        S
# ...

# %%
# Min - Max Method
ks1["Fare"] = (ks1["Fare"] - ks1["Fare"].min())/(ks1["Fare"].max()-ks1["Fare"].min() )
ks1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  age in days  \
# 0                            Braund, Mr. Owen Harris    male         8030
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female        13870
# 2                             Heikkinen, Miss. Laina  female         9490
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female        12775
# 4                           Allen, Mr. William Henry    male        12775
#
#    SibSp  Parch            Ticket      Fare Cabin Embarked
# 0      1      0         A/5 21171  0.014151   NaN        S
# 1      1      0          PC 17599  0.139136   C85        C
# 2      0      0  STON/O2. 3101282  0.015469   NaN        S
# 3      1      0            113803  0.103644  C123        S
# ...

# %%
ks1[["age in days","Fare"]]
# Out:
#      age in days      Fare
# 0           8030  0.014151
# 1          13870  0.139136
# 2           9490  0.015469
# 3          12775  0.103644
# 4          12775  0.015713
# ..           ...       ...
# 886         9855  0.025374
# 887         6935  0.058556
# 888        10840  0.045771
# 889         9490  0.058556
# 890        11680  0.015127
#
# [891 rows x 2 columns]

# %%
# Z score method

ks1["Fare"] = (ks1["Fare"] - ks1["Fare"].mean())/(ks1["Fare"].std() )

# %%
ks1[["age in days","Fare"]]
# Out:
#      age in days      Fare
# 0           8030 -0.502163
# 1          13870  0.786404
# 2           9490 -0.488580
# 3          12775  0.420494
# 4          12775 -0.486064
# ..           ...       ...
# 886         9855 -0.386454
# 887         6935 -0.044356
# 888        10840 -0.176164
# 889         9490 -0.044356
# 890        11680 -0.492101
#
# [891 rows x 2 columns]

# %%
# log transformation

ks["Fare"] = np.log (ks["Fare"])
ks.head()
# Out:
# C:\Users\JPC\AppData\Roaming\Python\Python311\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket      Fare Cabin Embarked
# 0      0         A/5 21171  1.981001   NaN        S
# ...
